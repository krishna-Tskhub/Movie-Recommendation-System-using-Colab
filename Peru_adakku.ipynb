# %% [markdown]
# <a href="https://colab.research.google.com/github/krishna-Tskhub/CSE310/blob/main/Peru_adakku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
nunique gives no of unique items in the dataset
round(_,n) -> rounds offs decimal by n
value_counts -> gives the count of each movie id

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ratings = pd.read_csv('https://s3-us-west-2.amazonaws.com/recommender-tutorial/ratings.csv')

# %%
movies = pd.read_csv('https://s3-us-west-2.amazonaws.com/recommender-tutorial/movies.csv')

# %%
n_ratings = len(ratings)  # chechking no.of ratings
n_movies = ratings['movieId'].nunique() #for no.of unique movies
n_users = ratings['userId'].nunique() #for no.of unique users

print(f"Number of ratings: {n_ratings}")
print(f"Number of unique movieId's: {n_movies}")
print(f"Number of unique users: {n_users}")
print(f"Average number of ratings per user: {round(n_ratings/n_users, 2)}")
print(f"Average number of ratings per movie: {round(n_ratings/n_movies, 2)}")
# Out:
# Number of ratings: 100836
# Number of unique movieId's: 9724
# Number of unique users: 610
# Average number of ratings per user: 165.3
# Average number of ratings per movie: 10.37

# %%
#seeing the rating distribution
sns.countplot( x='rating', data=ratings)
plt.title("Distribution of ratings", fontsize=12)
plt.show()

# %%
print(f"Mean global rating: {round(ratings['rating'].mean(),2)}.")
mean_ratings = ratings.groupby('userId')['rating'].mean()
print(f"Mean rating per user: {round(mean_ratings.mean(),2)}.")
# Out:
# Mean global rating: 3.5.
# Mean rating per user: 3.66.

# %%
#finding frquently watched movies
ratings['movieId'].value_counts()
# Out:
# movieId
# 356       329
# 318       317
# 296       307
# 593       279
# 2571      278
#          ...
# 86279       1
# 86922       1
# 5962        1
# 87660       1
# 163981      1
# Name: count, Length: 9724, dtype: int64

# %%
movie_ratings=ratings.merge(movies, on='movieId') #it is likea join statement in sql
movie_ratings

movie_ratings['title'].value_counts()[0:10] #this returns top 10 movies
# Out:
# title
# Forrest Gump (1994)                          329
# Shawshank Redemption, The (1994)             317
# Pulp Fiction (1994)                          307
# Silence of the Lambs, The (1991)             279
# Matrix, The (1999)                           278
# Star Wars: Episode IV - A New Hope (1977)    251
# Jurassic Park (1993)                         238
# Braveheart (1995)                            237
# Terminator 2: Judgment Day (1991)            224
# Schindler's List (1993)                      220
# Name: count, dtype: int64

# %%
mean_ratings = ratings.groupby('movieId')[['rating']].mean()
lowest_rated = mean_ratings['rating'].idxmin()

movies[movies['movieId'] ==  lowest_rated]
# Out:
#       movieId         title   genres
# 2689     3604  Gypsy (1962)  Musical

# %%
highest_rated =mean_ratings['rating'].idxmax()
movies[movies['movieId'] == highest_rated]
# Out:
#     movieId            title           genres
# 48       53  Lamerica (1994)  Adventure|Drama

# %%
ratings[ratings['movieId']==highest_rated]
# Out:
#        userId  movieId  rating  timestamp
# 13368      85       53     5.0  889468268
# 96115     603       53     5.0  963180003

# %%
movie_stats =
movie_stats.head()
